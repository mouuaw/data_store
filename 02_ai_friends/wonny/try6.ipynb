# %%
import numpy as np
import pandas as pd
import math

import seaborn as sns
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from scipy.stats import chi2_contingency
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

def get_model_cv_prediction(model, X_data, y_target):
    neg_mse_scores = cross_val_score(model, X_data, y_target, scoring="neg_mean_squared_error", cv = 5)
    rmse_scores = np.sqrt(-1 * neg_mse_scores)
    avg_rmse = np.mean(rmse_scores)
    print('##### ', model.__class__.__name__, ' #####')
    print(' 5 교차 검증의 평균 RMSE : {0:.3f} '.format(avg_rmse))

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

def get_stacking_base_datasets(model, X_train_n, y_train_n, X_test_n, n_folds):
    kf = KFold(n_splits=n_folds, shuffle=False, random_state=0)
    train_fold_pred = np.zeros((X_train_n.shape[0], 1))
    test_pred = np.zeros((X_test_n.shape[0], n_folds))
    # print(model.__class__.__name__, ' model 시작 ')

    for folder_counter, (train_index, valid_index) in enumerate(kf.split(X_train_n)):
        # print('\t 폴드 세트: ', folder_counter, ' 시작 ')
        X_tr = X_train_n[train_index]
        y_tr = y_train_n[train_index]
        X_te = X_train_n[valid_index]

        model.fit(X_tr, y_tr)

        train_fold_pred[valid_index, :] = model.predict(X_te).reshape(-1, 1)
        test_pred[:, folder_counter] = model.predict(X_test_n)

    test_pred_mean = np.mean(test_pred, axis=1).reshape(-1, 1)

    return train_fold_pred, test_pred_mean

# %%
train = pd.read_csv('../data/train.csv', index_col='id')
test = pd.read_csv('../data/test.csv', index_col='id')
submission = pd.read_csv('../data/sample_submission.csv', index_col='id')

# %%
train_upper = train[train['Y18'].isnull()]
train_upper = train_upper.drop(['X04', 'X14', 'X16', 'X19', 'X36', 'Y18'], axis=1)

# %%
train_upper.columns
# Out:
# Index(['X00', 'X01', 'X02', 'X03', 'X05', 'X06', 'X07', 'X08', 'X09', 'X10',
#        'X11', 'X12', 'X13', 'X15', 'X17', 'X18', 'X20', 'X21', 'X22', 'X23',
#        'X24', 'X25', 'X26', 'X27', 'X28', 'X29', 'X30', 'X31', 'X32', 'X33',
#        'X34', 'X35', 'X37', 'X38', 'X39', 'Y00', 'Y01', 'Y02', 'Y03', 'Y04',
#        'Y05', 'Y06', 'Y07', 'Y08', 'Y09', 'Y10', 'Y11', 'Y12', 'Y13', 'Y14',
#        'Y15', 'Y16', 'Y17'],
#       dtype='object')

# %%
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import Lasso

xgbr = XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=0.7, gamma=0,
             importance_type='gain', learning_rate=0.1, max_delta_step=0,
             max_depth=3, min_child_weight=1, missing=None, n_estimators=1500,
             n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
             silent=None, subsample=1, verbosity=1)

lgbmr = LGBMRegressor(colsample_bylevel= 0.5, colsample_bytree= 0.7, max_depth= 3, n_estimators= 1500)

lasso_reg = Lasso(alpha= 0.001)

# %%
def three_model_auto(X_train_n, X_test_n, y_train_n):
    fold = 5
    lasso_train, lasso_test = get_stacking_base_datasets(lasso_reg, X_train_n, y_train_n, X_test_n, fold)
    xgb_train, xgb_test = get_stacking_base_datasets(xgbr, X_train_n, y_train_n, X_test_n, fold)
    lgbm_train, lgbm_test = get_stacking_base_datasets(lgbmr, X_train_n, y_train_n, X_test_n, fold)

    Stack_final_X_train = np.concatenate((lasso_train, xgb_train, lgbm_train), axis=1)
    Stack_final_X_test = np.concatenate((lasso_test, xgb_test, lgbm_test), axis=1)

    return Stack_final_X_train, Stack_final_X_test

# %%
columnList = train_upper.columns
target_var_list = ['Y00', 'Y01', 'Y02', 'Y03', 'Y04', 'Y05', 'Y06', 'Y07', 'Y08', 'Y09', 'Y10', 'Y11', 'Y12', 'Y13', 'Y14', 'Y15', 'Y16', 'Y17']

input_var = list(filter(lambda x: target_var_list.count(x) == 0, columnList))

# %%
X_features = train_upper[input_var]
y_target = train_upper['Y00']

# X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.3, random_state=0)
# print("X_train :: ",X_train.head())
# print("X_test :: ",X_test.head())
# print("y_train :: ",y_train.head())
# print("y_test :: ",y_test.head())


print("X_features :: ",X_features.head())
print("test_input :: ",test[input_var].head())
# Out:
# X_features ::      X00    X01  X02  X03     X05    X06   X07     X08     X09  X10  ...  \
# id                                                                  ...
# 0   9.7  988.8  1.2  0.6  1009.3  989.6  12.2  1009.9  1009.8  0.0  ...
# 1   9.3  988.9  1.7  1.9  1009.3  989.6  12.1  1010.0  1009.9  0.0  ...
# 2   9.4  989.0  1.1  2.3  1009.2  989.7  12.1  1010.1  1010.1  0.0  ...
# 3   9.4  988.9  1.5  0.7  1009.2  989.6  12.0  1010.0  1010.0  0.0  ...
# 4   9.2  988.9  0.8  1.7  1009.2  989.7  12.0  1010.1  1010.0  0.0  ...
#
#        X29   X30  X31   X32     X33  X34    X35   X37   X38  X39
# id
# 0   1001.6  69.1  8.2  10.7  1010.1  0.0  256.4  77.2  62.6  0.0
# 1   1001.7  70.3  8.3  10.3  1010.1  0.0  215.4  77.3  63.5  0.0
# 2   1001.6  71.5  8.0   9.7  1010.0  0.0  235.2  77.3  63.9  0.0
# 3   1001.5  73.2  7.7   9.4  1010.1  0.0  214.0  77.5  64.5  0.0
# 4   1001.5  74.3  7.4   9.4  1010.1  0.0  174.9  78.0  65.0  0.0
#
# [5 rows x 35 columns]
# test_input ::         X00    X01  X02  X03     X05    X06   X07     X08     X09  X10  ...  \
# id                                                                     ...
# 4752  18.7  987.4  1.5  1.3  1006.8  987.7  21.1  1007.5  1007.2  0.0  ...
# 4753  18.8  987.4  1.1  1.2  1006.7  987.7  21.2  1007.5  1007.2  0.0  ...
# 4754  19.0  987.4  1.3  1.2  1006.6  987.6  21.2  1007.4  1007.2  0.0  ...
# 4755  18.7  987.4  2.3  0.8  1006.6  987.6  21.1  1007.4  1007.2  0.0  ...
# 4756  18.4  987.4  1.1  0.7  1006.7  987.7  20.9  1007.5  1007.2  0.0  ...
#
#         X29   X30   X31   X32     X33  X34    X35   X37   X38  X39
# id
# 4752  999.5  91.4  17.5  19.2  1007.6  0.0  194.7  84.0  59.9  0.0
# 4753  999.4  91.6  17.4  19.1  1007.5  0.0  173.1  84.0  60.5  0.0
# 4754  999.3  92.0  17.2  19.0  1007.5  0.0  208.6  85.0  60.8  0.0
# 4755  999.3  93.0  17.2  18.8  1007.4  0.0  185.0  85.8  61.2  0.0
# 4756  999.2  92.3  17.4  18.9  1007.5  0.0  162.8  87.3  61.7  0.0
#
# [5 rows x 35 columns]

# %%
columnList = train_upper.columns
target_var_list = ['Y00', 'Y01', 'Y02', 'Y03', 'Y04', 'Y05', 'Y06', 'Y07', 'Y08', 'Y09', 'Y10', 'Y11', 'Y12', 'Y13', 'Y14', 'Y15', 'Y16', 'Y17']

input_var = list(filter(lambda x: target_var_list.count(x) == 0, columnList))

test_input = test.drop(['X04', 'X14', 'X16', 'X19', 'X36'], axis=1)
X_features = train_upper[input_var]
X_features
# Out:
#        X00    X01  X02  X03     X05    X06   X07     X08     X09  X10  ...  \
# id                                                                     ...
# 0      9.7  988.8  1.2  0.6  1009.3  989.6  12.2  1009.9  1009.8  0.0  ...
# 1      9.3  988.9  1.7  1.9  1009.3  989.6  12.1  1010.0  1009.9  0.0  ...
# 2      9.4  989.0  1.1  2.3  1009.2  989.7  12.1  1010.1  1010.1  0.0  ...
# 3      9.4  988.9  1.5  0.7  1009.2  989.6  12.0  1010.0  1010.0  0.0  ...
# 4      9.2  988.9  0.8  1.7  1009.2  989.7  12.0  1010.1  1010.0  0.0  ...
# 5      9.1  988.9  1.3  0.7  1009.1  989.6  12.0  1010.0  1010.0  0.0  ...
# 6      9.1  988.8  2.4  1.9  1009.1  989.6  12.0  1010.1  1010.0  0.0  ...
# 7      8.9  988.9  1.0  1.2  1009.2  989.7  11.9  1010.1  1010.1  0.0  ...
# 8      9.0  988.9  1.5  0.1  1009.2  989.6  11.9  1010.0  1010.1  0.0  ...
# 9      8.8  988.9  1.4  0.4  1009.4  989.6  11.8  1010.1  1010.1  0.0  ...
# 10     8.7  989.0  1.9  0.6  1009.2  989.7  11.8  1010.2  1010.2  0.0  ...
# 11     8.8  988.9  1.6  1.8  1009.0  989.6  11.8  1010.1  1010.1  0.0  ...
# 12     8.7  988.8  1.9  0.3  1008.9  989.5  11.7  1010.0  1010.0  0.0  ...
# 13     8.6  988.8  1.5  1.2  1008.8  989.5  11.7  1010.1  1010.0  0.0  ...
# 14     9.2  988.7  1.6  1.8  1008.7  989.4  11.8  1010.0  1009.9  0.0  ...
# 15     9.1  988.6  1.9  0.5  1008.7  989.4  11.8  1010.0  1009.8  0.0  ...
# 16     9.3  988.6  2.5  1.5  1008.8  989.4  11.8  1010.0  1009.8  0.0  ...
# 17     9.0  988.5  1.3  1.2  1008.8  989.3  11.7  1009.9  1009.8  0.0  ...
# 18     9.0  988.5  1.7  1.8  1008.7  989.2  11.7  1009.8  1009.8  0.0  ...
# 19     8.7  988.4  2.6  1.9  1008.7  989.1  11.6  1009.7  1009.7  0.0  ...
# 20     8.8  988.3  3.0  1.6  1008.6  989.0  11.8  1009.6  1009.5  0.0  ...
# 21     8.6  988.3  2.3  1.9  1008.4  989.0  11.9  1009.6  1009.6  0.0  ...
# 22     8.4  988.3  3.0  1.4  1008.5  989.0  11.9  1009.7  1009.6  0.0  ...
# 23     8.4  988.3  1.6  0.7  1008.6  989.1  11.9  1009.8  1009.6  0.0  ...
# 24     8.6  988.2  3.0  1.0  1008.6  989.0  11.9  1009.7  1009.5  0.0  ...
# 25     8.5  988.3  3.1  1.1  1008.6  989.1  11.9  1009.8  1009.6  0.0  ...
# 26     8.5  988.4  2.4  0.8  1008.7  989.1  11.9  1009.8  1009.7  0.0  ...
# 27     8.6  988.4  2.3  0.9  1008.6  989.1  11.9  1009.8  1009.7  0.0  ...
# 28     8.9  988.3  2.8  1.5  1008.6  989.0  11.9  1009.7  1009.6  0.0  ...
# 29     8.8  988.3  2.2  1.8  1008.6  989.0  11.9  1009.7  1009.6  0.0  ...
# ...    ...    ...  ...  ...     ...    ...   ...     ...     ...  ...  ...
# 4290  25.5  986.4  0.2  1.2  1005.9  986.7  25.0  1006.1  1005.6  0.0  ...
# 4291  25.2  986.4  0.6  1.1  1006.0  986.8  24.9  1006.2  1005.7  0.0  ...
# 4292  24.9  986.4  0.7  1.5  1005.9  986.8  24.8  1006.2  1005.7  0.0  ...
# 4293  24.6  986.4  0.7  0.6  1005.8  986.8  24.6  1006.3  1005.8  0.0  ...
# 4294  24.2  986.4  0.0  1.3  1005.8  986.9  24.3  1006.4  1005.9  0.0  ...
# 4295  23.8  986.3  0.0  1.9  1005.8  986.9  24.1  1006.5  1005.8  0.0  ...
# 4296  23.5  986.4  0.0  1.0  1005.8  986.8  23.9  1006.4  1005.9  0.0  ...
# 4297  23.2  986.4  0.0  1.1  1005.8  986.8  23.8  1006.5  1006.0  0.0  ...
# 4298  23.0  986.4  0.9  1.1  1005.7  986.9  23.8  1006.6  1006.0  0.0  ...
# 4299  22.8  986.5  1.3  1.5  1005.9  986.8  23.5  1006.5  1006.1  0.0  ...
# 4300  22.6  986.5  1.1  1.2  1006.1  987.0  23.4  1006.7  1006.2  0.0  ...
# 4301  22.4  986.7  1.0  1.2  1006.3  987.0  23.3  1006.8  1006.4  0.0  ...
# 4302  22.2  986.8  1.1  2.2  1006.5  987.1  23.2  1006.9  1006.5  0.0  ...
# 4303  21.7  986.9  1.7  2.0  1006.6  987.2  23.0  1007.0  1006.6  0.0  ...
# 4304  21.6  987.0  1.6  1.8  1006.8  987.4  22.9  1007.2  1006.6  0.0  ...
# 4305  21.5  987.1  2.1  1.1  1006.8  987.5  22.8  1007.4  1006.7  0.0  ...
# 4306  21.3  987.1  2.6  1.5  1007.1  987.7  22.6  1007.6  1006.7  0.0  ...
# 4307  21.1  987.3  1.6  0.3  1007.1  987.8  22.5  1007.7  1006.9  0.0  ...
# 4308  20.8  987.4  1.8  1.5  1007.3  987.8  22.3  1007.5  1007.1  0.0  ...
# 4309  20.5  987.4  1.6  0.0  1007.3  987.9  22.0  1007.7  1007.1  0.0  ...
# 4310  20.6  987.4  1.4  0.7  1007.5  988.1  22.0  1007.9  1007.1  0.0  ...
# 4311  20.5  987.7  1.6  1.8  1007.6  988.0  21.9  1007.8  1007.4  0.0  ...
# 4312  20.4  987.7  1.9  1.3  1007.8  988.0  21.8  1007.8  1007.4  0.0  ...
# 4313  20.4  987.9  2.2  1.3  1007.6  988.1  21.6  1007.9  1007.6  0.0  ...
# 4314  20.1  987.7  2.0  0.8  1007.7  988.0  21.4  1007.7  1007.4  0.0  ...
# 4315  19.5  987.8  1.7  0.4  1007.8  988.0  21.3  1007.8  1007.5  0.0  ...
# 4316  19.3  987.7  2.1  0.9  1007.8  988.1  21.3  1008.0  1007.4  0.0  ...
# 4317  19.5  987.8  0.9  1.3  1007.8  988.3  21.2  1008.1  1007.5  0.0  ...
# 4318  20.0  987.8  1.4  0.5  1007.8  988.3  21.1  1008.1  1007.5  0.0  ...
# 4319  20.1  987.8  1.2  1.2  1007.8  988.2  20.9  1008.1  1007.5  0.0  ...
#
#        Y08   Y09   Y10   Y11   Y12   Y13   Y14   Y15   Y16   Y17
# id
# 0     10.0   7.0   7.5   7.0   9.0  10.0   9.5   9.0   8.0   9.0
# 1      9.5   6.5   7.5   7.0   8.5  10.0   9.5   9.0   7.5   9.0
# 2      9.0   6.5   7.5   6.5   8.0   9.5   9.5   8.5   7.5   8.5
# 3      9.0   6.0   7.0   6.0   8.0   9.5   9.0   8.5   7.5   8.5
# 4      8.5   6.0   7.0   6.0   7.5   9.5   9.0   8.5   7.5   8.5
# 5      8.5   6.0   7.0   6.0   7.5   9.0   9.0   8.5   7.0   8.5
# 6      8.5   5.5   6.5   5.5   7.5   9.0   8.5   8.0   7.0   8.0
# 7      8.5   5.5   6.0   5.5   7.5   9.0   8.5   8.0   7.0   8.0
# 8      8.0   5.0   6.0   5.0   7.0   9.0   8.5   8.0   7.0   8.0
# 9      8.0   4.5   5.5   5.0   7.0   8.5   8.5   8.0   7.0   8.0
# 10     8.0   4.5   5.5   5.0   7.0   8.5   8.5   8.0   6.5   8.0
# 11     7.5   4.5   5.5   4.5   7.0   8.5   8.5   8.0   7.0   8.0
# 12     7.5   4.5   5.5   4.5   7.0   8.5   8.5   8.0   7.0   8.0
# 13     7.5   4.5   5.5   4.5   6.5   8.5   8.5   8.0   6.5   8.0
# 14     7.5   4.5   5.0   4.5   6.5   8.5   8.5   8.0   6.5   8.0
# 15     7.5   4.5   5.0   4.0   6.5   8.5   8.5   8.0   6.5   8.0
# 16     7.5   4.5   5.0   4.0   6.5   8.5   8.5   7.5   6.5   7.5
# 17     7.5   4.5   5.0   4.0   6.5   8.0   8.0   7.5   6.5   7.5
# 18     7.5   4.0   5.0   4.0   6.0   8.0   8.0   7.5   6.5   7.5
# 19     7.5   4.5   5.0   4.0   6.0   8.0   8.0   7.5   6.5   7.5
# 20     7.0   4.5   4.5   4.0   6.0   8.0   8.0   7.5   6.0   7.5
# 21     7.0   4.0   4.5   3.5   6.0   8.0   8.0   7.0   6.0   7.5
# 22     7.0   4.0   4.5   3.5   6.0   8.0   7.5   7.0   6.0   7.0
# 23     7.0   4.0   4.5   3.5   6.0   7.5   7.5   7.0   6.0   7.0
# 24     7.0   4.0   4.5   3.5   6.0   7.5   7.5   7.0   6.0   7.0
# 25     7.0   4.0   4.5   3.5   6.0   7.5   7.5   7.0   6.0   7.0
# 26     7.0   4.0   4.0   3.0   6.0   7.5   8.0   7.0   6.0   7.5
# 27     7.0   3.5   4.0   3.0   6.0   7.5   8.0   7.0   6.0   7.5
# 28     7.0   4.0   4.0   3.0   6.0   7.5   8.0   7.0   6.0   7.0
# 29     7.0   4.5   4.5   3.0   6.0   7.5   8.0   7.0   6.0   7.0
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4290  27.0  26.0  29.0  29.5  25.0  23.5  24.0  23.5  25.5  25.0
# 4291  26.5  25.5  28.5  29.0  25.0  23.0  23.5  23.5  25.5  24.5
# 4292  26.0  25.0  28.0  28.5  25.0  23.0  23.0  23.5  25.0  24.5
# 4293  25.5  25.0  27.5  28.0  25.0  23.0  23.0  23.0  24.5  24.0
# 4294  25.0  24.5  27.0  27.5  24.5  22.5  23.0  22.5  24.0  23.5
# 4295  24.5  24.0  26.5  26.5  23.5  22.5  22.5  22.5  23.5  22.5
# 4296  24.0  23.5  25.5  26.0  23.0  22.0  22.5  22.0  23.0  22.0
# 4297  23.5  23.0  25.0  25.5  22.5  22.0  22.0  21.5  22.5  21.5
# 4298  23.0  22.5  24.5  25.0  22.0  21.5  21.5  21.5  22.0  21.0
# 4299  22.5  22.0  24.0  24.5  22.0  21.0  21.5  21.0  22.0  21.0
# 4300  22.0  21.5  23.5  24.0  21.5  21.0  21.0  21.0  21.5  20.5
# 4301  22.0  21.5  23.0  23.5  21.5  21.0  21.0  21.0  21.0  20.5
# 4302  21.5  21.0  23.0  22.5  21.0  20.5  21.0  20.5  20.5  20.5
# 4303  21.5  20.5  22.5  22.0  21.0  20.5  20.5  20.5  20.5  20.0
# 4304  21.0  20.5  22.0  22.0  21.0  20.5  20.5  20.5  20.0  20.0
# 4305  21.0  20.0  21.5  21.5  21.0  20.5  20.5  20.5  20.0  20.0
# 4306  21.0  20.0  21.0  21.0  21.0  21.0  21.0  20.5  20.0  20.0
# 4307  21.0  20.0  21.0  21.0  20.5  21.0  21.0  20.5  20.5  20.0
# 4308  21.0  20.0  20.5  20.5  20.5  20.5  21.0  20.5  20.5  20.0
# 4309  21.0  20.0  20.5  20.5  20.5  20.5  21.0  20.5  21.0  20.0
# 4310  21.0  20.0  20.5  20.5  20.5  20.5  20.5  20.5  20.5  20.0
# 4311  21.0  20.0  20.5  20.0  20.5  20.5  20.5  20.0  20.5  20.0
# 4312  21.0  20.0  20.5  20.0  20.5  20.5  20.5  20.0  20.5  20.0
# 4313  20.5  20.0  20.5  19.5  20.5  20.5  20.5  20.0  20.5  20.0
# 4314  20.5  20.0  20.0  19.5  20.5  20.5  20.0  20.0  20.5  20.0
# 4315  20.5  19.5  20.0  19.0  20.5  20.5  20.0  20.0  20.5  20.0
# 4316  20.5  19.5  20.0  19.0  20.5  20.5  20.0  19.5  20.5  19.5
# 4317  20.5  19.5  20.0  19.0  20.0  20.0  19.5  19.5  20.0  19.0
# 4318  20.0  19.5  20.0  18.5  20.0  20.0  19.5  19.5  20.0  19.0
# 4319  20.0  19.5  20.0  18.5  19.5  19.5  19.5  19.5  19.5  19.0
#
# [4320 rows x 53 columns]

# %%
from sklearn.metrics import mean_squared_error

def stack_auto(X_features, X_test, y_target):

    X_train_n = X_features.values
    X_test_n = X_test.values
    y_train_n = y_target.values

    Stack_final_X_train, Stack_final_X_test = three_model_auto(X_train_n, X_test_n, y_train_n)

    meta_model_lgbmr = LGBMRegressor(colsample_bylevel= 0.5, colsample_bytree= 0.7, max_depth= 3, n_estimators= 1500)

    meta_model_lgbmr.fit(Stack_final_X_train, y_target)
    final = meta_model_lgbmr.predict(Stack_final_X_train)
    mse = mean_squared_error(y_target, final)
    rmse = np.sqrt(mse)
    print('스태킹 회귀 모델 최종 RMSE :: ',rmse)

    return meta_model_lgbmr

# %%
X_features = train_upper[input_var]

trainNotNull = train[train['Y18'].notnull()]
trainNotNull = trainNotNull.drop(['X04', 'X14', 'X16', 'X19', 'X36'], axis=1)
trainNotNull


for target_col in target_var_list:
    print(target_col)

    y_target = train_upper[target_col]
    model = stack_auto(X_features, test_input, y_target)

    X_train_n = train_upper[input_var].values
    X_test_n = trainNotNull[input_var].values
    y_train_n = train_upper[target_col].values

    final_X_train, final_X_test = three_model_auto(X_train_n, X_test_n, y_train_n)

    pred = model.predict(final_X_test)
    trainNotNull[target_col] = pred
# Out:
# win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:56:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.7090953643756879
# [19:57:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:57:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y07
# [19:58:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:58:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  2.4046914136651436
# [19:59:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:59:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y08
# [20:00:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:00:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  2.373834363585924
# [20:01:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:01:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y09
# [20:02:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:03:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.4428999027855829
# [20:03:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:20] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:04:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y10
# [20:04:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:32] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.6410069191781216
# [20:05:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:06:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y11
# [20:06:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:12] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:07:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.9523652540121246
# [20:07:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y12
# [20:08:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  2.0584313502918388
# [20:09:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:09:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y13
# [20:10:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.9872671590028124
# [20:11:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:11:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y14
# [20:12:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:12:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.3614650232705945
# [20:13:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y15
# [20:14:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:14:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.2604191356174996
# [20:15:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:15:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y16
# [20:16:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:16:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.437818611401416
# [20:17:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y17
# [20:18:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:18:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  1.885828630100493
# [20:19:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:19:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
trainNotNull
# Out:
#        X00    X01  X02  X03     X05    X06   X07     X08     X09  X10  ...  \
# id                                                                     ...
# 4320  19.3  987.7  0.9  2.2  1007.7  988.0  20.8  1007.8  1007.4  0.0  ...
# 4321  19.0  987.6  1.9  2.2  1007.7  988.0  20.6  1007.8  1007.4  0.0  ...
# 4322  19.1  987.6  2.0  1.4  1007.8  988.1  20.5  1007.9  1007.4  0.0  ...
# 4323  19.2  987.7  1.8  1.5  1007.9  988.1  20.5  1007.9  1007.5  0.0  ...
# 4324  19.2  987.8  1.4  1.4  1007.9  988.1  20.5  1007.8  1007.6  0.0  ...
# 4325  19.0  987.9  1.5  1.2  1007.8  988.1  20.4  1008.0  1007.7  0.0  ...
# 4326  19.1  987.9  1.2  1.0  1007.8  988.1  20.3  1008.0  1007.7  0.0  ...
# 4327  19.3  987.8  0.7  0.6  1007.8  988.1  20.4  1008.0  1007.6  0.0  ...
# 4328  19.1  987.7  2.7  0.1  1007.7  988.1  20.4  1008.0  1007.5  0.0  ...
# 4329  18.8  987.7  1.2  0.8  1007.6  988.1  20.4  1008.0  1007.5  0.0  ...
# 4330  18.8  987.6  2.0  0.6  1007.6  988.1  20.4  1007.8  1007.4  0.0  ...
# 4331  18.6  987.5  1.2  0.8  1007.6  988.0  20.4  1007.8  1007.3  0.0  ...
# 4332  18.2  987.5  1.4  1.3  1007.5  988.0  20.4  1007.7  1007.3  0.0  ...
# 4333  18.0  987.5  1.8  1.0  1007.4  987.9  20.4  1007.8  1007.3  0.0  ...
# 4334  18.0  987.4  0.5  0.7  1007.2  987.9  20.4  1007.8  1007.2  0.0  ...
# 4335  17.7  987.2  0.2  0.8  1007.0  987.9  20.4  1007.8  1007.1  0.0  ...
# 4336  17.8  987.2  0.8  0.4  1007.1  988.0  20.3  1007.9  1007.1  0.0  ...
# 4337  17.6  987.3  1.1  0.8  1007.2  988.0  20.2  1007.9  1007.2  0.0  ...
# 4338  17.4  987.3  1.1  0.0  1007.3  987.8  20.1  1007.7  1007.2  0.0  ...
# 4339  17.4  987.5  0.5  0.6  1007.5  987.8  20.0  1007.6  1007.4  0.0  ...
# 4340  17.4  987.6  0.6  0.7  1007.6  987.8  19.9  1007.6  1007.5  0.0  ...
# 4341  17.2  987.8  0.4  1.1  1007.6  987.8  19.9  1007.6  1007.7  0.0  ...
# 4342  17.4  987.8  0.2  0.5  1007.6  987.9  19.9  1007.7  1007.7  0.0  ...
# 4343  17.2  987.7  0.5  0.8  1007.7  987.9  19.9  1007.7  1007.6  0.0  ...
# 4344  17.1  987.7  0.5  0.3  1007.7  987.9  19.9  1007.7  1007.6  0.0  ...
# 4345  17.0  987.7  1.1  0.3  1007.8  988.0  19.9  1007.8  1007.6  0.0  ...
# 4346  17.0  987.8  1.2  0.7  1007.8  988.0  19.9  1007.8  1007.7  0.0  ...
# 4347  16.9  987.9  1.0  0.9  1007.9  988.2  19.8  1008.0  1007.8  0.0  ...
# 4348  16.7  987.9  0.9  1.7  1007.9  988.3  19.6  1008.1  1007.8  0.0  ...
# 4349  16.5  988.0  0.3  0.0  1007.8  988.3  19.5  1008.1  1007.9  0.0  ...
# ...    ...    ...  ...  ...     ...    ...   ...     ...     ...  ...  ...
# 4722  25.7  985.3  0.3  0.8  1004.4  985.8  25.0  1005.4  1004.7  0.0  ...
# 4723  25.4  985.4  2.2  0.0  1004.4  985.8  24.5  1005.5  1004.8  0.0  ...
# 4724  25.2  985.5  0.7  0.7  1004.4  986.2  24.1  1005.9  1005.0  0.0  ...
# 4725  25.2  985.7  1.7  1.5  1004.6  986.1  23.8  1005.8  1005.2  1.0  ...
# 4726  25.0  985.6  1.5  1.7  1004.6  986.0  23.5  1005.7  1005.2  1.5  ...
# 4727  24.9  985.8  1.6  1.0  1004.8  986.4  23.3  1006.1  1005.4  2.0  ...
# 4728  24.7  985.9  2.2  1.4  1004.9  986.4  23.2  1006.1  1005.5  2.5  ...
# 4729  24.5  986.0  2.2  1.0  1005.0  986.6  23.1  1006.3  1005.7  2.5  ...
# 4730  24.2  986.1  1.4  1.0  1005.1  986.7  23.0  1006.5  1005.8  2.5  ...
# 4731  24.0  986.1  1.0  1.3  1005.3  986.7  23.0  1006.5  1005.7  2.5  ...
# 4732  24.1  986.5  1.2  1.5  1005.4  986.7  23.0  1006.5  1006.0  2.5  ...
# 4733  23.4  986.9  1.5  0.4  1005.6  986.7  23.0  1006.5  1006.5  2.5  ...
# 4734  23.2  987.0  0.8  0.8  1005.7  987.2  23.0  1007.1  1006.7  2.5  ...
# 4735  22.0  987.2  1.3  0.6  1005.8  987.3  22.8  1007.2  1006.8  2.5  ...
# 4736  21.7  987.3  2.5  2.2  1006.0  987.5  22.6  1007.4  1006.9  2.5  ...
# 4737  21.6  987.5  1.8  2.6  1006.1  987.7  22.5  1007.6  1007.2  2.5  ...
# 4738  21.5  987.7  2.0  2.4  1006.3  987.7  22.5  1007.6  1007.4  2.5  ...
# 4739  21.3  987.7  2.6  2.4  1006.4  987.7  22.4  1007.6  1007.4  2.5  ...
# 4740  21.1  987.7  1.4  2.7  1006.6  987.9  22.3  1007.8  1007.4  2.5  ...
# 4741  21.0  987.7  1.6  2.0  1006.6  987.9  22.2  1007.8  1007.4  2.5  ...
# 4742  20.9  987.7  0.2  2.0  1006.6  987.8  22.2  1007.7  1007.4  2.5  ...
# 4743  20.8  987.6  2.6  2.0  1006.8  987.6  22.0  1007.3  1007.3  2.5  ...
# 4744  20.5  987.7  1.1  2.0  1006.8  987.8  21.9  1007.7  1007.4  2.5  ...
# 4745  20.2  987.8  1.1  1.6  1006.9  987.8  21.7  1007.7  1007.6  2.5  ...
# 4746  20.1  987.9  0.3  1.1  1006.9  987.7  21.7  1007.4  1007.7  2.5  ...
# 4747  19.9  987.6  0.9  0.8  1006.9  987.7  21.7  1007.5  1007.4  2.5  ...
# 4748  19.9  987.6  0.5  0.7  1006.8  987.7  21.6  1007.5  1007.4  2.5  ...
# 4749  19.7  987.7  0.9  0.6  1006.9  987.6  21.4  1007.4  1007.5  2.5  ...
# 4750  19.4  987.7  0.9  0.8  1006.9  987.8  21.3  1007.6  1007.5  2.5  ...
# 4751  19.1  987.6  1.0  0.3  1006.8  987.8  21.2  1007.5  1007.4  2.5  ...
#
#             Y09        Y10        Y11        Y12        Y13        Y14  \
# id
# 4320  18.024362  19.016616  18.707396  18.266830  19.493777  18.833328
# 4321  18.561098  19.156632  18.771770  18.634934  19.344874  18.758819
# 4322  18.764516  20.171874  18.485021  19.980204  19.372882  18.669037
# 4323  18.850351  18.986766  18.266430  19.834118  19.344874  18.669037
# 4324  18.838112  20.171874  18.525876  19.405385  19.159680  18.646099
# 4325  18.826109  19.557012  18.406596  19.839679  19.159680  18.773703
# 4326  18.561098  19.767994  18.218662  19.437144  19.249303  18.679527
# 4327  18.493920  20.112263  18.266430  19.744001  19.283814  18.648551
# 4328  18.564053  19.402727  18.425798  20.171782  19.301722  18.648551
# 4329  18.308893  18.236791  18.652354  19.019723  19.283814  18.761271
# 4330  19.022079  18.633229  18.286464  19.084074  19.273850  18.711837
# 4331  18.520323  18.244375  17.985139  19.759390  19.227564  18.807131
# 4332  18.345278  18.196769  17.433116  18.847962  19.169860  18.646099
# 4333  18.452644  18.396975  18.552823  19.440807  19.159680  18.773703
# 4334  18.542160  18.517656  17.944283  19.253154  19.159680  18.758819
# 4335  18.124813  18.533671  17.619249  19.421974  19.227564  18.758819
# 4336  19.015726  18.357473  17.917397  19.532353  19.310703  18.677102
# 4337  18.715722  18.618632  18.429701  19.788832  19.273850  18.773703
# 4338  18.508666  18.211757  17.730434  19.506919  19.075420  18.599830
# 4339  17.010918  18.175934  17.537903  18.352908  18.585422  18.415076
# 4340  17.775557  18.175934  17.537903  18.652253  18.552480  18.319021
# 4341  17.635843  18.263741  17.329444  17.895518  18.731995  18.319021
# 4342  17.065663  17.736050  17.329444  17.958689  18.495771  18.256260
# 4343  17.439127  17.381146  17.329444  18.173098  18.493651  18.319021
# 4344  17.961478  18.389942  17.374610  18.451793  18.735144  18.622768
# 4345  16.922564  17.914349  17.329444  17.982263  18.470812  18.393801
# 4346  17.767803  17.687185  17.234949  18.003810  18.470812  18.389294
# 4347  16.922755  17.605210  17.329444  17.329335  18.735545  18.010648
# 4348  16.676656  17.780546  17.295764  17.440416  18.519133  18.010648
# 4349  17.103068  17.292078  17.295764  17.406447  18.464502  17.845362
# ...         ...        ...        ...        ...        ...        ...
# 4722  23.661934  25.245374  26.565753  20.153103  24.961939  24.909287
# 4723  21.873779  23.484199  24.176329  20.278810  23.043445  24.920910
# 4724  20.973545  22.416388  22.948075  20.078646  22.498189  24.227178
# 4725  20.421866  21.806836  21.639878  19.729803  22.559103  23.766207
# 4726  20.549479  22.821386  24.820097  19.081876  22.118981  23.631416
# 4727  20.434887  21.493292  21.627788  19.374187  21.703860  21.431157
# 4728  20.539973  21.614880  22.612850  18.568972  22.219684  23.219544
# 4729  20.275219  21.591986  23.235911  19.868489  21.757174  22.292501
# 4730  19.100267  19.972888  20.875650  20.166746  20.542010  21.754885
# 4731  20.078357  21.045407  21.969186  19.964056  20.979975  21.377132
# 4732  19.766980  21.373771  22.057743  20.108168  21.442823  22.184317
# 4733  19.629260  21.404531  22.409520  19.396572  21.597633  23.917405
# 4734  19.233990  19.290332  21.775584  19.253623  21.458131  23.685626
# 4735  19.134539  19.738191  19.761759  18.314140  20.972665  22.445843
# 4736  19.557089  20.298489  20.185402  18.312147  20.972665  23.208642
# 4737  19.119849  18.853807  19.597437  17.158540  20.216289  22.077622
# 4738  19.600653  19.366294  19.791564  18.970703  20.541036  22.232313
# 4739  19.627612  19.408072  19.897769  17.180759  21.253159  21.407142
# 4740  18.868057  20.134817  19.470782  18.003358  20.203945  21.544667
# 4741  19.126690  18.927883  19.386707  17.586998  19.772285  20.818645
# 4742  18.904253  19.325901  19.538202  17.757460  19.953056  21.039293
# 4743  18.892095  19.805003  19.202133  17.832034  19.953056  20.796354
# 4744  19.054345  19.868814  19.425210  19.133568  19.772285  20.861796
# 4745  18.131455  18.846112  18.737646  19.127175  19.911819  20.514121
# 4746  18.189292  18.751575  18.328179  19.236731  19.476089  20.495326
# 4747  18.236263  18.870272  18.580673  19.184046  19.632745  20.122357
# 4748  18.139739  18.856898  18.580673  18.426151  19.579476  19.942026
# 4749  18.339301  18.330295  18.293577  18.392478  19.287921  19.865447
# 4750  18.333011  18.317775  18.884173  18.844048  19.310703  19.893668
# 4751  18.316745  18.360687  18.293577  18.689441  19.159680  19.852399
#
#             Y15        Y16        Y17   Y18
# id
# 4320  19.157150  19.492274  18.524280  20.5
# 4321  18.861898  19.356637  19.266974  20.5
# 4322  18.772897  19.309103  18.497922  20.5
# 4323  19.011264  19.235606  18.875372  20.5
# 4324  19.061131  19.316650  18.962914  20.5
# 4325  18.967355  19.465124  18.906076  20.5
# 4326  18.923413  19.256234  18.557909  20.5
# 4327  19.423429  19.601100  18.962066  20.5
# 4328  19.080972  19.601100  18.939172  20.5
# 4329  18.772897  19.256234  19.035289  20.5
# 4330  18.786545  18.550388  18.235977  20.5
# 4331  18.513970  18.621077  18.638721  20.5
# 4332  18.646301  18.526220  18.087722  20.5
# 4333  18.922801  19.048001  18.524280  20.5
# 4334  18.608441  19.186627  18.786225  20.5
# 4335  18.759849  19.196898  18.310523  20.5
# 4336  18.967948  19.133810  18.786225  20.0
# 4337  19.020702  18.907632  18.594244  20.0
# 4338  19.020702  18.646309  18.274006  20.0
# 4339  18.032444  17.819231  18.157043  19.5
# 4340  18.234818  17.830367  17.895466  19.0
# 4341  18.016249  17.823973  17.896974  19.0
# 4342  18.008912  17.847790  18.157043  19.0
# 4343  18.022558  17.292917  17.679811  19.0
# 4344  19.070130  18.413397  18.257759  19.0
# 4345  18.513571  18.118785  18.265251  19.0
# 4346  18.277474  17.430218  17.848753  19.0
# 4347  18.022558  17.735558  17.595772  19.0
# 4348  18.008999  17.386640  17.746669  19.0
# 4349  17.699144  17.210367  17.916306  19.0
# ...         ...        ...        ...   ...
# 4722  19.061991  21.864713  20.323559  26.0
# 4723  19.993264  22.405348  19.697438  25.5
# 4724  19.098666  20.857751  20.026668  25.5
# 4725  19.113510  21.846575  19.781625  25.0
# 4726  19.027884  21.524760  19.827941  24.5
# 4727  18.489920  21.195339  19.492483  24.5
# 4728  19.120390  21.846575  20.160036  24.0
# 4729  19.030114  19.887046  20.469222  24.0
# 4730  18.579854  19.932524  19.122572  23.5
# 4731  18.263354  20.639805  19.774469  23.5
# 4732  18.252215  20.948303  19.758730  23.0
# 4733  18.837761  20.311550  20.349834  23.0
# 4734  18.510454  20.231402  19.706304  23.0
# 4735  19.634714  18.802815  18.978002  23.0
# 4736  19.700453  18.798535  19.655816  23.0
# 4737  18.880074  18.876222  19.295177  23.0
# 4738  19.429475  19.252471  19.820896  23.0
# 4739  19.452993  19.104175  19.519608  23.0
# 4740  18.913287  18.785131  19.105695  23.0
# 4741  18.973815  19.052327  19.526468  22.5
# 4742  19.047351  18.802815  19.824002  22.5
# 4743  18.968361  18.836374  18.315924  22.0
# 4744  19.047351  18.708774  18.469707  22.0
# 4745  18.865231  18.056925  17.867397  22.0
# 4746  18.456400  17.861773  17.951923  22.0
# 4747  18.082052  17.183176  18.084070  21.5
# 4748  18.065857  17.529032  18.040156  21.5
# 4749  18.015666  17.623997  17.900965  21.5
# 4750  18.005635  17.117271  17.987835  21.5
# 4751  17.991988  17.375116  17.918876  21.0
#
# [432 rows x 54 columns]

# %%
# test

trainNotNull_X_features = trainNotNull[input_var]

for target_col in target_var_list:
    print(target_col)
    trainNotNull_y_target = trainNotNull[target_col]
    model = stack_auto(trainNotNull_X_features, test_input, trainNotNull_y_target)

    X_train_n = trainNotNull[input_var].values
    X_test_n = test[input_var].values
    y_train_n = trainNotNull[target_col].values

    final_X_train, final_X_test = three_model_auto(X_train_n, X_test_n, y_train_n)

    pred = model.predict(final_X_test)
    test[target_col] = pred
# Out:
# 4_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.6420223162478942
# [20:36:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:36:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y07
# [20:37:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.8567847365235595
# [20:37:20] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y08
# [20:37:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.9612652265499358
# [20:37:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:37:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y09
# [20:38:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.47663732159265226
# [20:38:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y10
# [20:38:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:38:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.6085186610790525
# [20:39:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y11
# [20:39:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.8842396135571593
# [20:39:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y12
# [20:39:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:39:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.7407231447003322
# [20:40:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y13
# [20:40:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:32] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.3974545216861552
# [20:40:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:40:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y14
# [20:40:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.5492027282958716
# [20:41:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:20] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y15
# [20:41:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.6103677216787506
# [20:41:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:41:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y16
# [20:42:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:12] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.5372330056569986
# [20:42:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y17
# [20:42:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.8196228165729676
# [20:42:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:42:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:43:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
test
# Out:
#         X00    X01  X02  X03  X04     X05    X06   X07     X08     X09  ...  \
# id                                                                      ...
# 4752   18.7  987.4  1.5  1.3  0.0  1006.8  987.7  21.1  1007.5  1007.2  ...
# 4753   18.8  987.4  1.1  1.2  0.0  1006.7  987.7  21.2  1007.5  1007.2  ...
# 4754   19.0  987.4  1.3  1.2  0.0  1006.6  987.6  21.2  1007.4  1007.2  ...
# 4755   18.7  987.4  2.3  0.8  0.0  1006.6  987.6  21.1  1007.4  1007.2  ...
# 4756   18.4  987.4  1.1  0.7  0.0  1006.7  987.7  20.9  1007.5  1007.2  ...
# 4757   18.6  987.4  1.3  0.0  0.0  1006.8  987.7  20.7  1007.5  1007.2  ...
# 4758   18.6  987.3  1.0  0.8  0.0  1006.7  987.6  20.6  1007.4  1007.1  ...
# 4759   18.7  987.5  1.5  0.8  0.0  1006.7  987.5  20.5  1007.4  1007.3  ...
# 4760   18.5  987.5  1.2  1.6  0.0  1006.8  987.4  20.4  1007.3  1007.4  ...
# 4761   18.5  987.5  1.5  0.0  0.0  1006.8  987.5  20.4  1007.4  1007.4  ...
# 4762   18.7  987.5  0.9  0.3  0.0  1007.0  987.5  20.3  1007.4  1007.4  ...
# 4763   18.9  987.4  1.1  0.8  0.0  1006.9  987.4  20.3  1007.3  1007.4  ...
# 4764   19.2  987.4  0.3  1.0  0.0  1006.9  987.3  20.2  1007.2  1007.4  ...
# 4765   19.4  987.4  0.1  1.0  0.0  1006.9  987.3  20.0  1007.2  1007.4  ...
# 4766   19.5  987.3  0.3  0.3  0.0  1006.9  987.3  20.1  1007.2  1007.3  ...
# 4767   19.5  987.4  0.0  0.0  0.0  1006.9  987.3  19.8  1007.2  1007.4  ...
# 4768   19.4  987.4  0.0  0.6  0.0  1006.9  987.4  19.7  1007.3  1007.4  ...
# 4769   19.4  987.4  1.0  0.0  0.0  1006.8  987.4  19.8  1007.3  1007.4  ...
# 4770   19.4  987.4  1.0  0.2  0.0  1006.9  987.4  19.6  1007.3  1007.5  ...
# 4771   19.5  987.4  0.8  0.5  0.0  1007.0  987.4  19.4  1007.3  1007.5  ...
# 4772   19.4  987.4  0.8  1.6  0.0  1007.0  987.5  19.3  1007.4  1007.5  ...
# 4773   19.5  987.5  0.7  1.0  0.0  1007.1  987.6  19.2  1007.5  1007.6  ...
# 4774   19.5  987.7  0.6  0.6  0.0  1007.3  987.7  19.1  1007.6  1007.8  ...
# 4775   19.5  987.8  1.7  2.0  0.0  1007.4  987.8  19.1  1007.7  1007.8  ...
# 4776   19.5  987.9  0.9  1.9  0.0  1007.5  987.8  19.2  1007.7  1008.0  ...
# 4777   19.5  988.0  1.0  0.7  0.0  1007.5  987.9  19.0  1007.8  1008.1  ...
# 4778   19.5  988.0  0.6  1.2  0.0  1007.6  988.1  18.9  1008.0  1008.1  ...
# 4779   19.5  988.1  0.6  0.5  0.0  1007.7  988.0  18.7  1007.9  1008.2  ...
# 4780   19.5  988.2  0.8  0.8  0.0  1007.8  988.1  18.7  1008.0  1008.3  ...
# 4781   19.6  988.3  0.7  1.6  0.0  1007.9  988.1  18.7  1008.0  1008.4  ...
# ...     ...    ...  ...  ...  ...     ...    ...   ...     ...     ...  ...
# 16242  27.4  992.0  0.4  1.3  0.0  1010.9  992.3  28.6  1011.7  1011.4  ...
# 16243  27.4  992.1  2.0  1.5  0.0  1011.0  992.5  28.6  1011.9  1011.5  ...
# 16244  27.0  992.2  0.7  1.5  0.0  1011.0  992.5  28.4  1012.0  1011.5  ...
# 16245  27.0  992.4  1.3  0.8  0.0  1011.2  992.6  28.3  1012.1  1011.7  ...
# 16246  27.2  992.5  0.7  1.1  0.0  1011.4  992.7  28.1  1012.3  1011.9  ...
# 16247  27.1  992.6  0.4  2.8  0.0  1011.4  992.8  28.0  1012.4  1012.0  ...
# 16248  27.0  992.6  0.1  1.1  0.0  1011.4  992.9  27.9  1012.5  1012.0  ...
# 16249  27.0  992.7  1.4  2.1  0.0  1011.5  993.0  27.7  1012.6  1012.1  ...
# 16250  26.8  992.8  1.4  0.8  0.0  1011.6  993.0  27.6  1012.5  1012.2  ...
# 16251  26.7  992.9  0.0  1.7  0.0  1011.6  993.1  27.5  1012.6  1012.3  ...
# 16252  26.7  992.8  0.0  0.7  0.0  1011.7  993.2  27.3  1012.7  1012.3  ...
# 16253  26.4  992.9  0.0  2.1  0.0  1011.7  993.3  27.3  1012.8  1012.4  ...
# 16254  26.4  992.9  0.0  1.2  0.0  1011.8  993.3  27.2  1012.8  1012.4  ...
# 16255  26.4  993.0  0.0  1.7  0.0  1011.8  993.4  27.0  1012.9  1012.5  ...
# 16256  26.5  993.0  0.9  1.5  0.0  1011.8  993.4  26.9  1013.0  1012.5  ...
# 16257  26.5  993.1  1.3  1.6  0.0  1011.8  993.5  26.8  1013.1  1012.6  ...
# 16258  26.5  993.1  1.8  1.2  0.0  1011.8  993.6  26.7  1013.2  1012.6  ...
# 16259  26.3  993.2  0.6  1.5  0.0  1011.9  993.7  26.6  1013.3  1012.7  ...
# 16260  26.2  993.3  2.3  3.8  0.0  1011.8  993.7  26.5  1013.3  1012.8  ...
# 16261  26.2  993.3  3.4  2.4  0.0  1011.9  993.8  26.5  1013.4  1012.8  ...
# 16262  26.0  993.3  3.4  3.8  0.0  1011.9  993.8  26.5  1013.4  1012.8  ...
# 16263  25.7  993.3  4.2  2.7  0.0  1011.9  993.8  26.5  1013.3  1012.8  ...
# 16264  25.9  993.3  4.2  3.7  0.0  1011.9  993.9  26.5  1013.4  1012.8  ...
# 16265  25.8  993.3  3.7  3.7  0.0  1011.8  993.9  26.5  1013.4  1012.8  ...
# 16266  25.7  993.2  3.9  3.7  0.0  1011.7  993.8  26.4  1013.3  1012.6  ...
# 16267  25.7  993.2  3.9  3.8  0.0  1011.7  993.8  26.3  1013.3  1012.6  ...
# 16268  25.6  993.2  3.0  3.0  0.0  1011.7  993.8  26.3  1013.3  1012.6  ...
# 16269  25.6  993.2  3.8  2.5  0.0  1011.9  993.7  26.2  1013.2  1012.7  ...
# 16270  25.5  993.2  2.4  2.8  0.0  1011.8  993.7  26.1  1013.2  1012.6  ...
# 16271  25.4  993.2  3.0  3.5  0.0  1011.9  993.6  26.0  1013.1  1012.6  ...
#
#              Y08        Y09        Y10        Y11        Y12        Y13  \
# id
# 4752   20.810480  18.589973  20.834686  21.158426  19.074035  19.743733
# 4753   20.640954  18.945430  20.254233  20.704838  19.493299  19.437392
# 4754   20.646925  19.059014  20.343408  20.234506  19.887911  19.153711
# 4755   20.157757  18.755443  19.991351  20.279525  19.463265  19.437392
# 4756   20.397901  18.552885  20.256246  21.104111  19.059931  19.043804
# 4757   19.761211  18.480741  20.098883  18.742098  19.493299  18.812625
# 4758   19.835520  18.325949  20.126553  19.717526  18.504135  18.619740
# 4759   19.755429  18.209733  20.098883  18.583011  18.443301  18.540791
# 4760   19.656321  18.346893  19.993771  18.640271  19.194002  18.542074
# 4761   19.673058  18.131959  19.726530  19.046563  19.041268  18.283820
# 4762   19.733168  18.008773  19.936152  18.832723  19.312105  18.481542
# 4763   19.733168  18.207982  19.581522  17.631156  19.737686  18.373903
# 4764   19.656321  17.944043  19.575293  17.491530  19.375850  18.270587
# 4765   19.734893  17.944043  19.289796  17.631156  19.171018  18.291140
# 4766   19.656321  18.083077  19.303882  17.834058  19.450559  18.660358
# 4767   19.504336  17.793505  18.912249  17.084614  18.393387  18.212625
# 4768   19.471954  17.793505  18.627908  17.240933  18.913351  18.291140
# 4769   19.191461  17.525166  18.590431  17.527295  18.554122  18.212625
# 4770   19.032773  17.525166  18.210687  17.449227  18.621186  18.255700
# 4771   19.032773  17.712620  18.615270  17.501585  18.473125  18.261405
# 4772   18.963560  17.525166  18.603114  17.193964  18.692604  18.404620
# 4773   18.835458  17.525166  17.814428  17.343195  18.571685  18.404620
# 4774   18.835458  17.525166  18.384938  17.253134  18.217208  18.388388
# 4775   18.826817  17.601260  18.210222  17.374071  19.158194  18.199814
# 4776   18.803076  17.862195  18.510904  17.410268  18.927375  18.368507
# 4777   18.835458  18.475942  18.524710  17.586473  18.504135  18.388388
# 4778   18.826817  18.475942  18.638711  17.449227  19.526257  18.199814
# 4779   18.818592  18.475942  18.184716  17.362568  19.199658  18.660418
# 4780   18.826817  18.098496  17.892446  18.119049  20.557766  18.199814
# 4781   18.826817  18.435441  18.347210  17.485094  19.568396  18.199814
# ...          ...        ...        ...        ...        ...        ...
# 16242  32.830434  29.859690  28.422011  29.862366  30.404283  28.311721
# 16243  31.721633  29.862561  30.689952  30.117256  30.012063  28.191673
# 16244  32.115920  31.213384  30.156679  30.680464  29.660578  27.901499
# 16245  32.712498  31.327045  30.033194  29.245670  30.675154  28.023810
# 16246  32.550176  31.089099  28.266273  28.108842  29.097117  25.721845
# 16247  32.712498  28.822355  29.118116  27.995515  26.192357  25.796049
# 16248  32.788940  30.105168  28.005547  28.959631  27.886337  25.796049
# 16249  32.557283  27.728987  27.030297  28.185061  25.282826  26.286868
# 16250  28.891618  27.679174  24.975302  28.925684  26.549099  26.187378
# 16251  28.891618  26.509343  26.192235  25.491653  25.557920  26.197973
# 16252  28.462734  26.678251  26.990232  25.210692  27.719141  26.289791
# 16253  28.419021  25.427380  26.620703  23.890611  28.178166  26.086609
# 16254  28.752749  25.703451  25.304045  23.156814  29.229280  26.079227
# 16255  28.154388  25.427380  25.288847  24.128339  27.869763  26.079227
# 16256  27.892044  25.924574  25.286319  24.392812  27.679810  26.079227
# 16257  27.722425  27.377198  25.341873  24.398592  27.715298  26.088454
# 16258  27.722425  26.502923  24.742173  24.398592  27.513545  26.197973
# 16259  28.157779  27.656087  26.678048  24.685536  28.676490  25.057081
# 16260  28.581631  26.203464  24.176717  24.748289  28.463442  25.057081
# 16261  28.743494  25.983562  22.040526  23.599525  25.310214  25.885271
# 16262  28.715270  25.983562  23.379118  23.481442  26.860316  26.030400
# 16263  24.351530  25.990704  23.379118  23.921726  25.310214  26.030400
# 16264  26.625487  24.982910  24.525634  23.502259  27.513545  25.996082
# 16265  26.610419  25.850043  24.424510  23.336455  27.513545  25.529821
# 16266  26.094751  25.850043  25.188473  24.241030  25.310214  25.857995
# 16267  28.353641  25.608369  22.976307  24.235250  25.559601  25.851762
# 16268  28.336452  27.859491  24.811762  23.501523  29.838536  26.163655
# 16269  28.272558  27.613233  25.108204  23.776704  29.406725  26.163655
# 16270  27.857266  27.703596  25.327213  24.776188  29.525898  26.086609
# 16271  28.516709  27.859491  26.700370  25.855834  30.054989  26.023396
#
#              Y14        Y15        Y16        Y17
# id
# 4752   18.931820  19.938210  18.908477  18.973299
# 4753   18.778500  19.938210  18.974492  18.877379
# 4754   18.753222  19.826470  18.963576  18.987541
# 4755   18.774489  19.811864  18.664110  18.889356
# 4756   18.744309  19.826409  18.649848  18.916155
# 4757   18.772141  19.702203  18.838739  18.837903
# 4758   18.783610  19.763850  18.600157  18.864702
# 4759   18.833859  19.643970  18.940482  18.916155
# 4760   18.552544  19.643970  18.189084  18.604016
# 4761   18.425272  19.324241  18.057854  18.446468
# 4762   18.535334  19.048881  18.057854  18.461431
# 4763   18.558989  18.988957  18.165154  18.507599
# 4764   18.313490  18.852620  18.165154  18.632306
# 4765   18.301139  18.534462  18.838739  18.632306
# 4766   18.317377  18.654503  19.055783  18.461431
# 4767   17.848346  18.593455  17.733926  18.444728
# 4768   18.201347  18.121260  18.838739  18.270665
# 4769   17.845859  18.088194  18.153980  17.665864
# 4770   17.848346  18.150218  17.904550  17.851537
# 4771   17.848346  18.150218  18.866358  18.305500
# 4772   17.848346  17.965315  18.745678  17.851537
# 4773   17.824691  18.088194  18.189084  18.051265
# 4774   17.817164  18.150218  18.900793  18.098800
# 4775   17.985760  17.963452  19.018525  18.270665
# 4776   17.893316  18.121260  18.676717  18.609408
# 4777   17.817164  18.256983  18.988771  18.461431
# 4778   17.985760  18.558586  19.174560  18.605507
# 4779   17.907206  18.593455  19.723802  18.766598
# 4780   17.985760  18.558586  19.289741  18.604016
# 4781   17.985760  18.982261  19.743521  18.489721
# ...          ...        ...        ...        ...
# 16242  26.725143  26.079045  30.767477  28.033413
# 16243  26.444635  26.066657  31.136122  27.480810
# 16244  26.768917  26.856657  28.590373  25.674589
# 16245  26.763322  27.118270  28.278641  25.117810
# 16246  28.047303  26.510900  28.376992  25.371605
# 16247  28.256394  26.510900  28.437067  23.360343
# 16248  25.632641  28.018307  29.123874  25.334913
# 16249  26.216209  26.513018  28.437067  23.825966
# 16250  26.868080  27.035915  28.631988  23.281967
# 16251  26.644336  26.307474  27.515781  25.013053
# 16252  26.280364  26.332235  27.515781  22.546640
# 16253  26.301762  25.871108  27.249547  23.931373
# 16254  25.655593  25.994338  27.515781  25.013053
# 16255  27.228942  26.072811  28.631988  25.013053
# 16256  27.853714  26.204021  28.569185  25.013053
# 16257  26.428737  25.600533  28.351510  22.234721
# 16258  25.839296  25.679006  28.437067  22.234721
# 16259  25.414153  26.203370  27.452979  21.168353
# 16260  25.228819  25.179692  29.244658  21.482283
# 16261  25.791651  24.679107  28.424155  23.728204
# 16262  25.486930  24.703573  28.698442  22.156696
# 16263  25.156042  25.228588  27.727265  21.752611
# 16264  25.228819  25.183428  28.273482  21.976969
# 16265  26.051899  25.183428  27.797324  21.103113
# 16266  25.791651  25.228588  29.115402  22.234721
# 16267  26.998443  25.228588  29.179417  23.316401
# 16268  26.211833  26.324302  29.744438  25.843670
# 16269  27.113641  26.324302  29.744438  25.581216
# 16270  27.905033  26.585986  28.992224  26.165569
# 16271  27.228942  26.784228  28.735868  25.838859
#
# [11520 rows x 58 columns]

# %%
trainNotNull

input_var_y = ['Y00', 'Y01', 'Y02', 'Y03', 'Y04', 'Y05', 'Y06', 'Y07', 'Y08', 'Y09', 'Y10', 'Y11', 'Y12', 'Y13', 'Y14', 'Y15', 'Y16', 'Y17']
target_var_y = ['Y18']

trainNotNull_features_y = trainNotNull[input_var_y]
trainNotNull_y_target = trainNotNull[target_var_y]
modelBB = stack_auto(trainNotNull_features_y, trainNotNull_features_y, trainNotNull_y_target)

trainNotNull_X_train_n = trainNotNull[input_var_y].values
trainNotNull_X_test_n = test[input_var_y].values
trainNotNull_y_train_n = trainNotNull[target_var_y].values

trainNotNull_final_X_train, trainNotNull_final_X_test = three_model_auto(trainNotNull_X_train_n, trainNotNull_X_test_n, trainNotNull_y_train_n)

pred = modelBB.predict(trainNotNull_final_X_test)
pred
# Out:
# [20:44:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 스태킹 회귀 모델 최종 RMSE ::  0.9289497864980866
# [20:44:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:44:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# array([20.99288906, 20.88184469, 20.92225391, ..., 28.88505748,
#        29.45419682, 29.36736865])

# %%
pred
# Out:
# array([20.99288906, 20.88184469, 20.92225391, ..., 28.88505748,
#        29.45419682, 29.36736865])

# %%
outputDf = pd.DataFrame()
outputDf['id'] = test.index
outputDf['Y18'] = pred
outputDf.to_csv('submission.csv', index=False)
